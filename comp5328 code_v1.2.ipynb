# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, normalized_mutual_info_score

# Load Data Function
def load_data(root='data/CroppedYaleB', reduce=4):
    """ 
    Load ORL (or Extended YaleB) dataset to numpy array.
    
    Args:
        root: path to dataset.
        reduce: scale factor for zooming out images.
        
    Returns:
        images: numpy array of shape (num_pixels, num_images).
        labels: numpy array of shape (num_images,).
    """ 
    images, labels = [], []

    for i, person in enumerate(sorted(os.listdir(root))):
        
        if not os.path.isdir(os.path.join(root, person)):
            continue
        
        for fname in os.listdir(os.path.join(root, person)):    
            
            # Remove background images in Extended YaleB dataset.
            if fname.endswith('Ambient.pgm'):
                continue
            
            if not fname.endswith('.pgm'):
                continue
                
            # Load image.
            img = Image.open(os.path.join(root, person, fname))
            img = img.convert('L')  # Convert to grayscale.

            # Reduce computation complexity.
            img = img.resize([s//reduce for s in img.size])

            # Preprocessing: Resize images to a fixed size to ensure consistency.
            fixed_size = (50, 50)  # (width, height)
            img = img.resize(fixed_size)

            # Convert image to numpy array.
            img = np.asarray(img).reshape((-1,1))

            # Collect data and label.
            images.append(img)
            labels.append(i)

    # Concatenate all images and labels.
    images = np.concatenate(images, axis=1)
    labels = np.array(labels)

    return images, labels

# NMF Algorithms

def standard_nmf(V, r, max_iter=100, tol=1e-4):
    """
    Standard NMF algorithm using multiplicative updates with convergence check.

    Objective Function:
        Minimize || V - W H ||_F^2
        where ||.||_F denotes the Frobenius norm.

    Optimization Method:
        Multiplicative Update Rules:
            H <- H * (W^T V) / (W^T W H)
            W <- W * (V H^T) / (W H H^T)
    """
    m, n = V.shape
    W = np.abs(np.random.rand(m, r)) + 1e-9  # Initialize W.
    H = np.abs(np.random.rand(r, n)) + 1e-9  # Initialize H.
    for i in range(max_iter):
        V_prev = W @ H
        # Update H.
        H *= (W.T @ V) / (W.T @ W @ H + 1e-9)  # Numerical stability.
        # Update W.
        W *= (V @ H.T) / (W @ H @ H.T + 1e-9)
        # Compute approximation.
        V_approx = W @ H
        # Check convergence.
        if np.linalg.norm(V_prev - V_approx, 'fro') / np.linalg.norm(V_prev, 'fro') < tol:
            print(f'Standard NMF converged at iteration {i+1}')
            break
    return W, H

def l21_norm_nmf(V, r, max_iter=100, epsilon=1e-9, tol=1e-4):
    """
    Robust NMF using L2,1-norm.

    Objective Function:
        Minimize || V - W H ||_{2,1}
        where ||X||_{2,1} = sum_i || X_{i,:} ||_2

    Optimization Method:
        Iteratively reweighted least squares with weight vector d:
            d_i = 1 / (2 || (V - W H)_{i,:} ||_2 )
        Update W and H by solving weighted least squares problems.
    """
    m, n = V.shape
    W = np.abs(np.random.rand(m, r)) + epsilon  # Initialize W.
    H = np.abs(np.random.rand(r, n)) + epsilon  # Initialize H.
    for i in range(max_iter):
        V_prev = W @ H
        # Compute residuals.
        R = V - V_prev  # (m x n)
        # Compute d vector.
        d = 1 / (2 * np.sqrt(np.sum(R**2, axis=1)) + epsilon)  # (m,)
        # Update W.
        Numerator = (d[:, np.newaxis] * V) @ H.T  # (m x r)
        Denominator = (d[:, np.newaxis] * W @ H) @ H.T + epsilon  # (m x r)
        W *= Numerator / Denominator
        # Update H.
        W_T_D = W.T * d[np.newaxis, :]  # (r x m)
        W_T_D_W = W_T_D @ W  # (r x r)
        W_T_D_V = W_T_D @ V  # (r x n)
        H = np.linalg.solve(W_T_D_W + epsilon * np.eye(r), W_T_D_V)
        H = np.maximum(H, epsilon)  # Ensure non-negativity.
        # Compute approximation.
        V_approx = W @ H
        # Check convergence.
        if np.linalg.norm(V_prev - V_approx, 'fro') / np.linalg.norm(V_prev, 'fro') < tol:
            print(f'L21-Norm NMF converged at iteration {i+1}')
            break
    return W, H

def l1_regularized_nmf(V, r, lambda_param=0.1, max_iter=100, epsilon=1e-9, tol=1e-4):
    """
    L1-Norm Regularized NMF.

    Objective Function:
        Minimize || V - W H ||_F^2 + lambda * || H ||_1

    Optimization Method:
        Multiplicative update rules with regularization to promote sparsity in H.

    Args:
        V: Data matrix (m x n).
        r: Rank of the factorization.
        lambda_param: Regularization parameter controlling sparsity.
        max_iter: Maximum number of iterations.
        epsilon: Small constant to prevent division by zero.
        tol: Tolerance for convergence.

    Returns:
        W: Basis matrix (m x r).
        H: Coefficient matrix (r x n).
    """
    m, n = V.shape
    W = np.abs(np.random.rand(m, r)) + epsilon  # Initialize W.
    H = np.abs(np.random.rand(r, n)) + epsilon  # Initialize H.

    for iteration in range(max_iter):
        V_prev = W @ H

        # Update H
        numerator_H = W.T @ V
        denominator_H = W.T @ W @ H + lambda_param + epsilon
        H *= numerator_H / denominator_H

        # Update W
        numerator_W = V @ H.T
        denominator_W = W @ H @ H.T + epsilon
        W *= numerator_W / denominator_W

        # Compute approximation
        V_approx = W @ H

        # Check convergence
        error = np.linalg.norm(V_prev - V_approx, 'fro') / np.linalg.norm(V_prev, 'fro')
        if error < tol:
            print(f'L1-Regularized NMF converged at iteration {iteration+1}')
            break

    return W, H

# Noise Functions

def add_block_occlusion(image, block_size):
    """Add block occlusion to a given image."""
    img_height, img_width = image.shape
    x = np.random.randint(0, img_width - block_size)
    y = np.random.randint(0, img_height - block_size)
    occluded_image = image.copy()
    occluded_image[y:y+block_size, x:x+block_size] = 255
    return occluded_image

def add_gaussian_noise(image, mean=0, std=25):
    """Add Gaussian noise to a given image."""
    noisy_image = image + np.random.normal(mean, std, image.shape)
    noisy_image = np.clip(noisy_image, 0, 255)
    return noisy_image

# Relative Reconstruction Error
def relative_reconstruction_error(V_clean, V_approx):
    """Calculate the relative reconstruction error."""
    return np.linalg.norm(V_clean - V_approx) / np.linalg.norm(V_clean)

# Evaluate Clustering Performance
def assign_cluster_label(X, Y):
    """
    Assign cluster labels based on KMeans clustering.

    Args:
        X: Data matrix (n_samples, n_features).
        Y: True labels.

    Returns:
        Y_pred: Predicted labels after aligning with true labels.
    """
    kmeans = KMeans(n_clusters=len(set(Y)), n_init=10, random_state=0).fit(X)
    Y_pred = np.zeros(Y.shape)
    for i in set(kmeans.labels_):
        ind = kmeans.labels_ == i
        Y_pred[ind] = Counter(Y[ind]).most_common(1)[0][0]  # Assign label.
    return Y_pred

# Main Function
if __name__ == "__main__":
    # Adjust the dataset paths accordingly.
    V_orl, Y_orl = load_data(root="C:/Users/fanti/Downloads/data/data/ORL", reduce=4)
    print('ORL Dataset loaded. V shape:', V_orl.shape)
    img_size = (50, 50)  # As specified in the preprocessing.
    image_shape_orl = img_size[::-1]  # (height, width)

    V_yale, Y_yale = load_data(root="C:/Users/fanti/Downloads/data/data/CroppedYaleB", reduce=4)
    print('Yale Dataset loaded. V shape:', V_yale.shape)
    image_shape_yale = img_size[::-1]  # (height, width)

    # List of datasets to process.
    datasets = [
        ('ORL', V_orl, Y_orl, image_shape_orl),
        ('YaleB', V_yale, Y_yale, image_shape_yale)
    ]

    # Block sizes for occlusion.
    block_sizes = [10, 12, 14]  # Different block sizes for experiments.

    # Number of repetitions for performance evaluation.
    num_repetitions = 5

    for dataset_name, V_data, Y_data, image_shape in datasets:
        print(f"\nProcessing {dataset_name} Dataset:")
        n_samples = V_data.shape[1]

        # Visualization of original images
        plt.figure(figsize=(8, 4))
        plt.imshow(V_data[:, 0].reshape(image_shape), cmap='gray')
        plt.title(f'Example Original Image ({dataset_name})')
        plt.axis('off')
        plt.show()

        # Apply different block-occlusion noises.
        for b_size in block_sizes:
            print(f"\nBlock Occlusion b={b_size} ({dataset_name})")
            RRE_list = {'Standard NMF': [], 'L21-Norm NMF': [], 'L1-Regularized NMF': []}
            ACC_list = {'Standard NMF': [], 'L21-Norm NMF': [], 'L1-Regularized NMF': []}
            NMI_list = {'Standard NMF': [], 'L21-Norm NMF': [], 'L1-Regularized NMF': []}

            for repetition in range(num_repetitions):
                print(f"\nRepetition {repetition+1}/{num_repetitions}")

                # Randomly sample 90% of the data
                indices = np.random.choice(n_samples, int(0.9 * n_samples), replace=False)
                V_sample = V_data[:, indices]
                Y_sample = Y_data[indices]

                # Choose an image to demonstrate occlusion
                img_index = np.random.choice(indices)
                img_original = V_data[:, img_index].reshape(image_shape)

                # Apply block occlusion noise
                img_occluded = add_block_occlusion(img_original, block_size=b_size)
                # Replace the occluded image in the dataset
                V_occluded = V_sample.copy()
                occluded_index = np.where(indices == img_index)[0][0]
                V_occluded[:, occluded_index] = img_occluded.flatten()

                # Display original and occluded images
                if repetition == 0:
                    plt.figure(figsize=(8, 4))
                    plt.subplot(1, 2, 1)
                    plt.imshow(img_original, cmap='gray')
                    plt.title(f'Original Image ({dataset_name})')
                    plt.axis('off')
                    plt.subplot(1, 2, 2)
                    plt.imshow(img_occluded, cmap='gray')
                    plt.title(f'Block Occluded Image b={b_size}')
                    plt.axis('off')
                    plt.show()

                # Run experiments for the occluded image.
                noise_name = f'Block Occlusion b={b_size}'
                # List of NMF algorithms to test.
                nmf_algorithms = {
                    'Standard NMF': standard_nmf,
                    'L21-Norm NMF': l21_norm_nmf,
                    'L1-Regularized NMF': l1_regularized_nmf
                }

                for algo_name, nmf_func in nmf_algorithms.items():
                    # Apply NMF algorithm.
                    if algo_name == 'L1-Regularized NMF':
                        W, H = nmf_func(V_occluded, r=40, lambda_param=0.1, max_iter=100)
                    else:
                        W, H = nmf_func(V_occluded, r=40, max_iter=100)
                    # Reconstruct the image.
                    reconstructed = W @ H[:, occluded_index]
                    # Calculate RRE.
                    RRE = relative_reconstruction_error(V_data[:, img_index], reconstructed)
                    RRE_list[algo_name].append(RRE)
                    # Evaluate clustering.
                    H_T = H.T
                    Y_pred = assign_cluster_label(H_T, Y_sample)
                    acc = accuracy_score(Y_sample, Y_pred)
                    nmi = normalized_mutual_info_score(Y_sample, Y_pred)
                    ACC_list[algo_name].append(acc)
                    NMI_list[algo_name].append(nmi)

                    # Display reconstructed image for the first repetition
                    if repetition == 0:
                        reconstructed_img = reconstructed.reshape(image_shape)
                        plt.figure(figsize=(4, 4))
                        plt.imshow(reconstructed_img, cmap='gray')
                        plt.title(f'{algo_name} Reconstruction')
                        plt.axis('off')
                        plt.show()

            # Compute average metrics and standard deviations
            for algo_name in nmf_algorithms.keys():
                avg_RRE = np.mean(RRE_list[algo_name])
                std_RRE = np.std(RRE_list[algo_name])
                avg_ACC = np.mean(ACC_list[algo_name])
                std_ACC = np.std(ACC_list[algo_name])
                avg_NMI = np.mean(NMI_list[algo_name])
                std_NMI = np.std(NMI_list[algo_name])

                print(f"\n{algo_name} - Average RRE: {avg_RRE:.4f} ± {std_RRE:.4f}")
                print(f"{algo_name} - Average Accuracy: {avg_ACC:.4f} ± {std_ACC:.4f}")
                print(f"{algo_name} - Average NMI: {avg_NMI:.4f} ± {std_NMI:.4f}")

        # Apply Gaussian noise.
        print(f"\nGaussian Noise ({dataset_name})")
        RRE_list = {'Standard NMF': [], 'L21-Norm NMF': [], 'L1-Regularized NMF': []}
        ACC_list = {'Standard NMF': [], 'L21-Norm NMF': [], 'L1-Regularized NMF': []}
        NMI_list = {'Standard NMF': [], 'L21-Norm NMF': [], 'L1-Regularized NMF': []}

        for repetition in range(num_repetitions):
            print(f"\nRepetition {repetition+1}/{num_repetitions}")

            # Randomly sample 90% of the data
            indices = np.random.choice(n_samples, int(0.9 * n_samples), replace=False)
            V_sample = V_data[:, indices]
            Y_sample = Y_data[indices]

            # Choose an image to demonstrate noise
            img_index = np.random.choice(indices)
            img_original = V_data[:, img_index].reshape(image_shape)

            # Apply Gaussian noise
            img_noisy = add_gaussian_noise(img_original, std=25)
            # Replace the noisy image in the dataset
            V_noisy = V_sample.copy()
            noisy_index = np.where(indices == img_index)[0][0]
            V_noisy[:, noisy_index] = img_noisy.flatten()

            # Display original and noisy images
            if repetition == 0:
                plt.figure(figsize=(8, 4))
                plt.subplot(1, 2, 1)
                plt.imshow(img_original, cmap='gray')
                plt.title(f'Original Image ({dataset_name})')
                plt.axis('off')
                plt.subplot(1, 2, 2)
                plt.imshow(img_noisy, cmap='gray')
                plt.title(f'Gaussian Noisy Image')
                plt.axis('off')
                plt.show()

            # Run experiments for the noisy image.
            noise_name = 'Gaussian Noise'
            # List of NMF algorithms to test.
            nmf_algorithms = {
                'Standard NMF': standard_nmf,
                'L21-Norm NMF': l21_norm_nmf,
                'L1-Regularized NMF': l1_regularized_nmf
            }

            for algo_name, nmf_func in nmf_algorithms.items():
                # Apply NMF algorithm.
                if algo_name == 'L1-Regularized NMF':
                    W, H = nmf_func(V_noisy, r=40, lambda_param=0.1, max_iter=100)
                else:
                    W, H = nmf_func(V_noisy, r=40, max_iter=100)
                # Reconstruct the image.
                reconstructed = W @ H[:, noisy_index]
                # Calculate RRE.
                RRE = relative_reconstruction_error(V_data[:, img_index], reconstructed)
                RRE_list[algo_name].append(RRE)
                # Evaluate clustering.
                H_T = H.T
                Y_pred = assign_cluster_label(H_T, Y_sample)
                acc = accuracy_score(Y_sample, Y_pred)
                nmi = normalized_mutual_info_score(Y_sample, Y_pred)
                ACC_list[algo_name].append(acc)
                NMI_list[algo_name].append(nmi)

                # Display reconstructed image for the first repetition
                if repetition == 0:
                    reconstructed_img = reconstructed.reshape(image_shape)
                    plt.figure(figsize=(4, 4))
                    plt.imshow(reconstructed_img, cmap='gray')
                    plt.title(f'{algo_name} Reconstruction')
                    plt.axis('off')
                    plt.show()

        # Compute average metrics and standard deviations
        for algo_name in nmf_algorithms.keys():
            avg_RRE = np.mean(RRE_list[algo_name])
            std_RRE = np.std(RRE_list[algo_name])
            avg_ACC = np.mean(ACC_list[algo_name])
            std_ACC = np.std(ACC_list[algo_name])
            avg_NMI = np.mean(NMI_list[algo_name])
            std_NMI = np.std(NMI_list[algo_name])

            print(f"\n{algo_name} - Average RRE: {avg_RRE:.4f} ± {std_RRE:.4f}")
            print(f"{algo_name} - Average Accuracy: {avg_ACC:.4f} ± {std_ACC:.4f}")
            print(f"{algo_name} - Average NMI: {avg_NMI:.4f} ± {std_NMI:.4f}")
# Out:
# ORL Dataset loaded. V shape: (2500, 400)
# Yale Dataset loaded. V shape: (2500, 2414)
#
# Processing ORL Dataset:
# Block Occlusion b=10 (ORL)
#
# Repetition 1/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 2/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 3/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 4/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 5/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Standard NMF - Average RRE: 0.2553 ± 0.0751
# Standard NMF - Average Accuracy: 0.7006 ± 0.0231
# Standard NMF - Average NMI: 0.8352 ± 0.0145
#
# L21-Norm NMF - Average RRE: 0.3353 ± 0.1046
# L21-Norm NMF - Average Accuracy: 0.6322 ± 0.0202
# L21-Norm NMF - Average NMI: 0.7747 ± 0.0103
#
# L1-Regularized NMF - Average RRE: 0.2395 ± 0.0396
# L1-Regularized NMF - Average Accuracy: 0.7117 ± 0.0140
# L1-Regularized NMF - Average NMI: 0.8428 ± 0.0049
#
# Block Occlusion b=12 (ORL)
#
# Repetition 1/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 2/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 3/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 4/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 5/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Standard NMF - Average RRE: 0.1938 ± 0.0389
# Standard NMF - Average Accuracy: 0.6961 ± 0.0154
# Standard NMF - Average NMI: 0.8372 ± 0.0081
#
# L21-Norm NMF - Average RRE: 0.2404 ± 0.0860
# L21-Norm NMF - Average Accuracy: 0.6483 ± 0.0082
# L21-Norm NMF - Average NMI: 0.7829 ± 0.0092
#
# L1-Regularized NMF - Average RRE: 0.1958 ± 0.0378
# L1-Regularized NMF - Average Accuracy: 0.7189 ± 0.0240
# L1-Regularized NMF - Average NMI: 0.8505 ± 0.0155
#
# Block Occlusion b=14 (ORL)
#
# Repetition 1/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 2/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 3/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 4/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 5/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Standard NMF - Average RRE: 0.2009 ± 0.0265
# Standard NMF - Average Accuracy: 0.7078 ± 0.0237
# Standard NMF - Average NMI: 0.8415 ± 0.0156
#
# L21-Norm NMF - Average RRE: 0.2542 ± 0.0436
# L21-Norm NMF - Average Accuracy: 0.6444 ± 0.0217
# L21-Norm NMF - Average NMI: 0.7819 ± 0.0142
#
# L1-Regularized NMF - Average RRE: 0.2092 ± 0.0252
# L1-Regularized NMF - Average Accuracy: 0.7006 ± 0.0204
# L1-Regularized NMF - Average NMI: 0.8353 ± 0.0167
#
# Gaussian Noise (ORL)
#
# Repetition 1/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 2/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 3/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 4/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Repetition 5/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Standard NMF - Average RRE: 0.1472 ± 0.0111
# Standard NMF - Average Accuracy: 0.7211 ± 0.0264
# Standard NMF - Average NMI: 0.8511 ± 0.0133
#
# L21-Norm NMF - Average RRE: 0.1333 ± 0.0157
# L21-Norm NMF - Average Accuracy: 0.6206 ± 0.0182
# L21-Norm NMF - Average NMI: 0.7696 ± 0.0141
#
# L1-Regularized NMF - Average RRE: 0.1470 ± 0.0133
# L1-Regularized NMF - Average Accuracy: 0.7256 ± 0.0240
# L1-Regularized NMF - Average NMI: 0.8509 ± 0.0124
#
# Processing YaleB Dataset:
# Block Occlusion b=10 (YaleB)
#
# Repetition 1/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 2/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 3/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 4/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 5/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Standard NMF - Average RRE: 0.3050 ± 0.1746
# Standard NMF - Average Accuracy: 0.1926 ± 0.0078
# Standard NMF - Average NMI: 0.2561 ± 0.0124
#
# L21-Norm NMF - Average RRE: 0.3408 ± 0.1959
# L21-Norm NMF - Average Accuracy: 0.1378 ± 0.0148
# L21-Norm NMF - Average NMI: 0.1794 ± 0.0234
#
# L1-Regularized NMF - Average RRE: 0.2961 ± 0.1626
# L1-Regularized NMF - Average Accuracy: 0.1959 ± 0.0053
# L1-Regularized NMF - Average NMI: 0.2560 ± 0.0111
#
# Block Occlusion b=12 (YaleB)
#
# Repetition 1/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 2/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 3/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 4/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 5/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Standard NMF - Average RRE: 0.4021 ± 0.0899
# Standard NMF - Average Accuracy: 0.1867 ± 0.0060
# Standard NMF - Average NMI: 0.2548 ± 0.0173
#
# L21-Norm NMF - Average RRE: 0.5900 ± 0.1146
# L21-Norm NMF - Average Accuracy: 0.1540 ± 0.0077
# L21-Norm NMF - Average NMI: 0.1987 ± 0.0078
#
# L1-Regularized NMF - Average RRE: 0.4018 ± 0.1041
# L1-Regularized NMF - Average Accuracy: 0.1898 ± 0.0054
# L1-Regularized NMF - Average NMI: 0.2504 ± 0.0043
#
# Block Occlusion b=14 (YaleB)
#
# Repetition 1/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# Repetition 2/5
# D:\python\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
